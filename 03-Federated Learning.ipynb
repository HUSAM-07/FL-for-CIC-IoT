# %% [markdown]
# # 03 - Federated Learning

# %% [markdown]
# Define the available types of federated learning.
#
#  - 'STRATIFIED': Stratified sampling of the data. The data is split into a number of shards, and each shard is assigned to a client. The data is split in a stratified manner, meaning that the distribution of the labels is approximately the same in each shard.
#  - 'LEAVE_ONE_OUT' - Each client is assigned a shard of data, each shard is missing one of the attack labels. Other clients in the network are exposed to the attack label, but the specific client is not. This demonstrates the ability of federated learning to protect against unknown attacks.
#  - 'ONE_CLASS' - Each client is assigned a shard of data, each shard contains only one of the attack labels.
#  - 'HALF_BENIGN' - Half of the clients are exposed to Benign data only, the other half are exposed to all data.

# %%
### THIS SECTION NEEDS TO BE SET TO DETERMINE WHICH CONFIGURATION METHOD TO UTILISE

SPLIT_AVAILABLE_METHODS = ['STRATIFIED','LEAVE_ONE_OUT', 'ONE_CLASS', 'HALF_BENIGN' ]
METHOD = 'STRATIFIED'
NUM_OF_STRATIFIED_CLIENTS = 10  # only applies to stratified method
NUM_OF_ROUNDS = 10              # Number of FL rounds

# %% [markdown]
# The above test method in conjunction with the below classification selection will determine the number of clients.
#
# EG:
# `STRATIFIED` with:
#  - `ALL TYPES` - Results in `NUM_OF_STRATIFIED_CLIENTS` clients. Each client will have a stratified sample of the data.
#
# `LEAVE_ONE_OUT` with:
#  - `individual_classifier` - Results in 33 clients. Each client will have benign traffic and 32 attack labels.
#  - `group_classifier` - Results in 7 clients. Each client will have benign traffic and 6 attack groups.
#  - `binary_classifier` - Results in 10 clients. Five clients will have benign traffic only and the other will have Benign and malicious attack labels.
#
# `ONE_CLASS` with:
#  - `individual_classifier` - Results in 33 clients. Each client will have benign traffic and 1 attack label.
#  - `group_classifier` - Results in 7 clients. Each client will have benign traffic and 1 attack groups.
#  - `binary_classifier` - Results in 10 clients. Five clients will have benign traffic only and the other will have Benign and malicious attack labels. - SAME AS LEAVE_ONE_OUT for binary classifier
#
# `HALF_BENIGN` with:
#  - `individual_classifier` - Results in 10 clients. Five clients will have benign traffic only and the other will have Benign and 33 malicious attack labels.
#  - `group_classifier` - Results in 10 clients. Five clients will have benign traffic only and the other will have Benign and 7 malicious attack groups.
#  - `binary_classifier` - Results in 10 clients. Five clients will have benign traffic only and the other will have Benign and malicious attack labels. - SAME AS LEAVE_ONE_OUT for binary classifier

# %%
individual_classifier = True
group_classifier = False
binary_classifier = False

# %% [markdown]
# Include the defines for the dataframe columns and the attack labels and their mappings

# %%
from enum import Enum
from includes import *

# %% [markdown]
# ##  Imports

# %%
# %%capture
# %pip install flwr[simulation]==1.4.0 torch==1.13.1 torchvision matplotlib sklearn openml numpy==1.24.2

# %%
# %pip install flwr torch torchvision
# Out:
# Requirement already satisfied: flwr in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (1.8.0)
# Requirement already satisfied: torch in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (2.3.0)
# Requirement already satisfied: torchvision in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (0.18.0)
# Requirement already satisfied: numpy<2.0.0,>=1.21.0 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from flwr) (1.23.5)
# Requirement already satisfied: typer[all]<0.10.0,>=0.9.0 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from flwr) (0.9.4)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from flwr) (2.0.1)
# Requirement already satisfied: protobuf<5.0.0,>=4.25.2 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from flwr) (4.25.3)
# Requirement already satisfied: cryptography<43.0.0,>=42.0.4 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from flwr) (42.0.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.60.0 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from flwr) (1.62.2)
# Requirement already satisfied: iterators<0.0.3,>=0.0.2 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from flwr) (0.0.2)
# Requirement already satisfied: pycryptodome<4.0.0,>=3.18.0 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from flwr) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: networkx in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: fsspec in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: jinja2 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: filelock in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.14.0)
# Requirement already satisfied: sympy in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from cryptography<43.0.0,>=42.0.4->flwr) (1.16.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.12.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from typer[all]<0.10.0,>=0.9.0->flwr) (8.1.7)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from typer[all]<0.10.0,>=0.9.0->flwr) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from typer[all]<0.10.0,>=0.9.0->flwr) (13.7.1)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from typer[all]<0.10.0,>=0.9.0->flwr) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12->cryptography<43.0.0,>=42.0.4->flwr) (2.21)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\unihu\appdata\roaming\python\python310\site-packages (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->flwr) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->flwr) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->flwr) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\UNIHU\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install --upgrade "protobuf<=3.20.1"
# Out:
# Collecting protobuf<=3.20.1
#   Downloading protobuf-3.20.1-cp310-cp310-win_amd64.whl (903 kB)
#      ------------------------------------ 903.8/903.8 KB 828.9 kB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed protobuf-3.20.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.1 which is incompatible.
# flwr 1.8.0 requires protobuf<5.0.0,>=4.25.2, but you have protobuf 3.20.1 which is incompatible.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\unihu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\UNIHU\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import os
os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"

# %%
# !export PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python
# Out:
# 'export' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %pip show torch==1.13.1
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: torch==1.13.1

# %%
# %pip install torchvision
# Out:
# Collecting torchvision
#   Using cached torchvision-0.18.0-cp310-cp310-win_amd64.whl (1.2 MB)
# Collecting torch==2.3.0
#   Using cached torch-2.3.0-cp310-cp310-win_amd64.whl (159.8 MB)
# Requirement already satisfied: numpy in c:\users\unihu\desktop\husamos\development\ciciot2023\latest\lib\site-packages (from torchvision) (1.26.4)
# Collecting pillow!=8.3.*,>=5.3.0
#   Using cached pillow-10.3.0-cp310-cp310-win_amd64.whl (2.5 MB)
# Collecting mkl<=2021.4.0,>=2021.1.1
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
# Collecting jinja2
#   Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Collecting fsspec
#   Using cached fsspec-2024.3.1-py3-none-any.whl (171 kB)
# Collecting sympy
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\unihu\desktop\husamos\development\ciciot2023\latest\lib\site-packages (from torch==2.3.0->torchvision) (4.11.0)
# Collecting filelock
#   Using cached filelock-3.14.0-py3-none-any.whl (12 kB)
# Collecting networkx
#   Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Collecting intel-openmp==2021.*
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl (3.5 MB)
# Collecting tbb==2021.*
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl (286 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl (17 kB)
# Collecting mpmath>=0.19
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: tbb, mpmath, intel-openmp, sympy, pillow, networkx, mkl, MarkupSafe, fsspec, filelock, jinja2, torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1
#     Uninstalling torch-1.13.1:
#       Successfully uninstalled torch-1.13.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\UNIHU\\Desktop\\HusamOs\\Development\\CICIoT2023\\latest\\Lib\\site-packages\\~orch\\lib\\asmjit.dll'
# Check the permissions.
#
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\UNIHU\Desktop\HusamOs\Development\CICIoT2023\latest\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import os
import pandas as pd
import numpy as np
import flwr as fl
from tqdm import tqdm
import warnings
#warnings.filterwarnings('ignore')

import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn
import torch.nn.functional as F
# import torchvision.transforms as transforms
from flwr.common import Metrics
from torch.utils.data import DataLoader, random_split

# %%
print("flwr", fl.__version__)
print("numpy", np.__version__)
print("torch", torch.__version__)

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Training on {DEVICE}")
# Out:
# flwr 1.4.0
# numpy 1.26.4
# torch 2.3.0+cpu
# Training on cpu

# %% [markdown]
# ## Load the Dataset

# %%
DATASET_DIRECTORY = 'datasets/'

# %% [markdown]
# ## Training data

# %% [markdown]
# Either read the training pickle file if it exists, or process the dataset from scratch.

# %%
# Check to see if the file 'training_data.pkl' exists in the directory. If it does, load it. If not, print an error.
if os.path.isfile('training_data.pkl'):
    print("File exists, loading data...")
    train_df = pd.read_pickle('training_data.pkl')
    print("Training data loaded from pickle file.")

else:
    df_sets = [k for k in os.listdir(DATASET_DIRECTORY) if k.endswith('.csv')]
    df_sets.sort()
    training_sets = df_sets[:int(len(df_sets)*.8)]
    test_sets = df_sets[int(len(df_sets)*.8):]

    # Print the number of files in each set
    print('Training sets: {}'.format(len(training_sets)))
    print('Test sets: {}'.format(len(test_sets)))

    # ######################
    # # TEMP CODE - This would replicate the original authors code with the last CSV 
    # # for training data. Uncomment this section to use this code.
    # ######################
    # # Set training_sets to the last entry of training_sets
    # training_sets = training_sets[-33:]
    # print(f"TO REPLICATE ORIGINAL AUTHORS CODE WITH ONE FILE TRAIN - {training_sets}")
    # #####################
    # # END TEMP CODE
    # ######################

    # Concatenate all training sets into one dataframe
    dfs = []
    print("Reading training data...")
    for train_set in tqdm(training_sets):
        df_new = pd.read_csv(DATASET_DIRECTORY + train_set)
        dfs.append(df_new)
    train_df = pd.concat(dfs, ignore_index=True)

    # Complete training data set size
    print("Complete training data size: {}".format(train_df.shape))

    # Map y column to the dict_34_classes values - The pickle file already has this done.
    train_df['label'] = train_df['label'].map(dict_34_classes)

    # The training data is the 80% of the CSV files in the dataset. The test data is the remaining 20%.
    # The Ray Federated learning mechanism cannot cope with all of the 80% training data, so we will split
    # the training data using test_train_split. The test data will be ignored as we will use all the data 
    # from the train_sets files as our training data to keep parity with the original authors code.
    # 
    # By using a subset of the training data split this way, we can have a randomised selection of data
    # from all the training CSV files, stratified by the attack types.
    
    # Percentage of original training data to use.
    TRAIN_SIZE = 0.05
    
    print(f"Splitting the data into {TRAIN_SIZE*100}%")
    
    X_train, X_test, y_train, y_test = train_test_split(train_df[X_columns], train_df[y_column], test_size= (1 - TRAIN_SIZE), random_state=42, stratify=train_df[y_column])

    # Recombine X_train, and y_train into a dataframe
    train_df = pd.concat([X_train, y_train], axis=1)

    # Clean up unused variables

    del X_train, y_train, X_test, y_test
    
    # Save the output to a pickle file
    print("Writing training data to pickle file...")
    train_df.to_pickle('training_data.pkl')

print("Training data size: {}".format(train_df.shape))
# Out:
# File exists, loading data...
# Training data loaded from pickle file.
# Training data size: (444704, 47)

# %%
# show the unique values counts in the label column for train_df
print("Counts of attacks in train_df:")
print(train_df['label'].value_counts())
# Out:
# Counts of attacks in train_df:
# label
# 6     68587
# 4     51022
# 5     42872
# 2     39323
# 3     38859
# 1     38401
# 7     34362
# 13    31567
# 15    25498
# 14    19312
# 0     10463
# 17     9502
# 19     8470
# 18     7174
# 10     4331
# 26     2920
# 9      2669
# 8      2663
# 25     1681
# 24     1272
# 21      970
# 22      870
# 16      703
# 23      378
# 12      267
# 11      199
# 33      129
# 27       50
# 32       46
# 29       46
# 31       41
# 28       25
# 20       20
# 30       12
# Name: count, dtype: int64

# %%
train_df
# Out:
#         flow_duration  Header_Length  Protocol Type  Duration         Rate  \
# 0            0.025926          56.06           6.00     63.82     3.528480
# 1            0.000000          54.00           6.00     64.00    26.996367
# 2            0.000000          54.00           6.00     64.00     2.986424
# 3            0.000000          53.46           5.94     63.36    66.531372
# 4            0.000000          81.00           6.00     64.00    10.473893
# ...               ...            ...            ...       ...          ...
# 444699       0.366179       35971.00          17.00     64.00  2904.981161
# 444700       0.000000           0.00           1.00     64.00     2.156362
# 444701       0.000000          54.00           6.00     64.00    18.178045
# 444702       1.937804     1935410.08          17.00     64.00  1762.710435
# 444703       0.000000          54.00           6.00     64.00     3.796846
#
#               Srate  Drate  fin_flag_number  syn_flag_number  rst_flag_number  \
# 0          3.528480    0.0              0.0              1.0              0.0
# 1         26.996367    0.0              0.0              1.0              0.0
# 2          2.986424    0.0              1.0              0.0              1.0
# 3         66.531372    0.0              0.0              1.0              0.0
# 4         10.473893    0.0              0.0              0.0              0.0
# ...             ...    ...              ...              ...              ...
# 444699  2904.981161    0.0              0.0              0.0              0.0
# 444700     2.156362    0.0              0.0              0.0              0.0
# 444701    18.178045    0.0              0.0              0.0              0.0
# 444702  1762.710435    0.0              0.0              0.0              0.0
# 444703     3.796846    0.0              0.0              0.0              0.0
#
#         ...       Std  Tot size           IAT  Number   Magnitue    Radius  \
# 0       ...  0.496995     54.20  8.298108e+07     9.5  10.405144  0.704371
# 1       ...  0.000000     54.00  8.308982e+07     9.5  10.392305  0.000000
# 2       ...  0.000000     54.00  8.334383e+07     9.5  10.392305  0.000000
# 3       ...  0.131850     54.06  8.309404e+07     9.5  10.395650  0.186918
# 4       ...  0.000000     54.00  8.292583e+07     9.5  10.392305  0.000000
# ...     ...       ...       ...           ...     ...        ...       ...
# 444699  ...  0.000000     50.00  8.309761e+07     9.5  10.000000  0.000000
# 444700  ...  0.000000     42.00  8.312488e+07     9.5   9.165151  0.000000
# 444701  ...  0.000000     54.00  8.306730e+07     9.5  10.392305  0.000000
# 444702  ...  0.000000    554.00  8.378930e+07     9.5  33.286634  0.000000
# 444703  ...  0.000000     54.00  8.303414e+07     9.5  10.392305  0.000000
#
#         Covariance  Variance  Weight  label
# 0         2.498950      0.10  141.55     14
# 1         0.000000      0.00  141.55      3
# 2         0.000000      0.00  141.55      1
# 3         0.195153      0.09  141.55      3
# 4         0.000000      0.00  141.55     15
# ...            ...       ...     ...    ...
# 444699    0.000000      0.00  141.55      4
# 444700    0.000000      0.00  141.55      6
# 444701    0.000000      0.00  141.55      5
# 444702    0.000000      0.00  141.55     19
# 444703    0.000000      0.00  141.55      5
#
# [444704 rows x 47 columns]

# %% [markdown]
# ---
# ## Test Data
# Concat the test data into a single dataframe

# %%
test_df['label'].value_counts()
len(test_df['label'].value_counts())
# Out:
# 34

# %%
pd.read_pickle("training_data.pkl") ["label"]
# Out:
# 0         14
# 1          3
# 2          1
# 3          3
# 4         15
#           ..
# 444699     4
# 444700     6
# 444701     5
# 444702    19
# 444703     5
# Name: label, Length: 444704, dtype: int64

# %%
# Check to see if the file 'test_data.pkl' exists in the directory. If it does, load it. If not, print an error.
testing_data_pickle_file = 'testing_data.pkl'

if os.path.isfile(testing_data_pickle_file):
    print(f"File {testing_data_pickle_file} exists, loading data...")
    test_df = pd.read_pickle(testing_data_pickle_file)
    print("Test data loaded from pickle file.")

else:
    print(f"File {testing_data_pickle_file} does not exist, constructing data...")

    df_sets = [k for k in os.listdir(DATASET_DIRECTORY) if k.endswith('.csv')]
    df_sets.sort()
    training_sets = df_sets[:int(len(df_sets)*.8)]
    test_sets = df_sets[int(len(df_sets)*.8):]

    # Print the number of files in each set
    print('Test sets: {}'.format(len(test_sets)))
    
    # Concatenate all testing sets into one dataframe
    dfs = []
    print("Reading test data...")
    for test_set in tqdm(test_sets):
        df_new = pd.read_csv(DATASET_DIRECTORY + test_set)
        dfs.append(df_new)
    test_df = pd.concat(dfs, ignore_index=True)

    # Map y column to the dict_34_classes values - The pickle file already has this done.
    test_df['label'] = test_df['label'].map(dict_34_classes)

    # Save the output to a pickle file
    print(f"Writing test data to pickle file {testing_data_pickle_file}...")
    test_df.to_pickle(testing_data_pickle_file)

print("Testing data size: {}".format(test_df.shape))
# Out:
# File testing_data.pkl does not exist, constructing data...
# Test sets: 32
# Reading test data...
# 100%|██████████| 32/32 [00:50<00:00,  1.57s/it]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 29
#      26 test_df = pd.concat(dfs, ignore_index=True)
#      28 # Map y column to the dict_34_classes values - The pickle file already has this done.
# ---> 29 test_df['label'] = test_df['label'].map(dict_34_classes)
#      31 # Save the output to a pickle file
#      32 print(f"Writing test data to pickle file {testing_data_pickle_file}...")
#
# NameError: name 'dict_34_classes' is not defined

# %%
print("Number of rows in train_df: {}".format(len(train_df)))
print("Number of rows in test_df: {}".format(len(test_df)))

train_size = len(train_df)
test_size = len(test_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print("Number of rows in train_df: {}".format(len(train_df)))
#       2 print("Number of rows in test_df: {}".format(len(test_df)))
#       4 train_size = len(train_df)
#
# NameError: name 'train_df' is not defined

# %% [markdown]
# ---
# # Scale the test and train data

# %% [markdown]
# ### Scale the training data input features

# %%
scaler = StandardScaler()
train_df[X_columns] = scaler.fit_transform(train_df[X_columns])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 scaler = StandardScaler()
#       2 train_df[X_columns] = scaler.fit_transform(train_df[X_columns])
#
# NameError: name 'StandardScaler' is not defined

# %% [markdown]
# ### Scale the testing data input features

# %%
test_df[X_columns] = scaler.fit_transform(test_df[X_columns])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 test_df[X_columns] = scaler.fit_transform(test_df[X_columns])
#
# NameError: name 'scaler' is not defined

# %% [markdown]
# ---
# # Define the classification problem - (2 classes, 8 classes or 34 classes)
# Change the following cell to select the classification type
#
# If the METHOD == STRATIFIED, then we can use any classifier
# If the METHOD == ATTACK_GROUP then we must use Group Classifier.

# %%
class_size_map = {2: "Binary", 8: "Group", 34: "Individual"}

if group_classifier:
    print("Group 8 Class Classifier... - Adjusting labels in test and train dataframes")
    # Map y column to the dict_7_classes values
    test_df['label'] = test_df['label'].map(dict_8_classes)
    train_df['label'] = train_df['label'].map(dict_8_classes)
    class_size = "8"      
    
elif binary_classifier:
    print("Binary 2 Class Classifier... - Adjusting labels in test and train dataframes")
    # Map y column to the dict_2_classes values
    test_df['label'] = test_df['label'].map(dict_2_classes)
    train_df['label'] = train_df['label'].map(dict_2_classes)
    class_size = "2"

else:
    print ("Individual 34 Class classifier... - No adjustments to labels in test and train dataframes")
    class_size = "34"
# Out:
# Binary 2 Class Classifier... - Adjusting labels in test and train dataframes

# %% [markdown]
# ---
# # Split the Training Data into partitions for the Federated Learning clients depending on the test required
# As a reminder:
#
# `STRATIFIED` with:
#  - `ALL TYPES` - Results in `NUM_OF_STRATIFIED_CLIENTS` clients. Each client will have a stratified sample of the data.
#
# `LEAVE_ONE_OUT` with:
#  - `individual_classifier` - Results in 33 clients. Each client will have benign traffic and 32 attack labels.
#  - `group_classifier` - Results in 7 clients. Each client will have benign traffic and 6 attack groups.
#  - `binary_classifier` - Results in 10 clients. Five clients will have benign traffic only and the other will have Benign and malicious attack labels.
#
# `ONE_CLASS` with:
#  - `individual_classifier` - Results in 33 clients. Each client will have benign traffic and 1 attack label.
#  - `group_classifier` - Results in 7 clients. Each client will have benign traffic and 1 attack groups.
#  - `binary_classifier` - Results in 10 clients. Five clients will have benign traffic only and the other will have Benign and malicious attack labels. - SAME AS LEAVE_ONE_OUT for binary classifier
#
# `HALF_BENIGN` with:
#  - `individual_classifier` - Results in 10 clients. Five clients will have benign traffic only and the other will have Benign and 33 malicious attack labels.
#  - `group_classifier` - Results in 10 clients. Five clients will have benign traffic only and the other will have Benign and 7 malicious attack groups.
#  - `binary_classifier` - Results in 10 clients. Five clients will have benign traffic only and the other will have Benign and malicious attack labels. - SAME AS LEAVE_ONE_OUT for binary classifier

# %%
from sklearn.model_selection import StratifiedKFold

# Define fl_X_train and fl_y_train
fl_X_train = []
fl_y_train = []

client_df = pd.DataFrame()

if METHOD == 'STRATIFIED':
    print(f"{Colours.YELLOW.value}STRATIFIED METHOD{Colours.NORMAL.value} with {class_size} class classifier")
    # We are going to split the training data into 'NUM_OF_STRATIFIED_CLIENTS' smaller groups using StratifiedKFold
    skf = StratifiedKFold(n_splits=NUM_OF_STRATIFIED_CLIENTS, shuffle=True, random_state=42)
    for train_index, test_index in skf.split(train_df[X_columns], train_df[y_column]):
        fl_X_train.append(train_df[X_columns].iloc[test_index])
        fl_y_train.append(train_df[y_column].iloc[test_index])

elif METHOD == 'LEAVE_ONE_OUT':
    print(f"{Colours.YELLOW.value}LEAVE_ONE_OUT METHOD{Colours.NORMAL.value} with {class_size} class classifier")

    if individual_classifier or group_classifier:
        # Set the number of splits required to the number of classes - 1
        num_splits = int(class_size) - 1
    else:
        # For binary classifier, set the number of splits to 10
        num_splits = 10

    skf = StratifiedKFold(n_splits=num_splits, shuffle=True, random_state=42)

    # When creating the clients, we will remove one attack class from the training data
    # For the binary classifier, evey other client will have the benign class removed
    for i, (train_index, test_index) in enumerate(skf.split(train_df[X_columns], train_df[y_column])):
        if binary_classifier:
            print(f"i: {i} = i % 2 = {i % 2}")
            if i % 2 == 0:
                print("Benign only")
                # Create a new dataframe for the client data with only benign traffic
                client_df = pd.concat([train_df.iloc[test_index][train_df[y_column] != 1]], ignore_index=True)
                fl_X_train.append(client_df[X_columns])
                fl_y_train.append(client_df[y_column])
            else:
                print("Both")
                # Create a new dataframe for the client data
                fl_X_train.append(train_df[X_columns].iloc[test_index])
                fl_y_train.append(train_df[y_column].iloc[test_index])
        else:
            # Create a new dataframe for the client data
            client_df = pd.concat([train_df.iloc[test_index][train_df[y_column] != i+1]], ignore_index=True)
            fl_X_train.append(client_df[X_columns])
            fl_y_train.append(client_df[y_column])

elif METHOD == 'ONE_CLASS':
    print(f"{Colours.YELLOW.value}ONE_CLASS METHOD{Colours.NORMAL.value} with {class_size} class classifier")
    # Each client only has one attack class in their training data along with the Benign data
    
    if individual_classifier or group_classifier:
        # Set the number of splits required to the number of classes - 1
        num_splits = int(class_size) - 1
    else:
        # For binary classifier, set the number of splits to 10
        num_splits = 10

    skf = StratifiedKFold(n_splits=num_splits, shuffle=True, random_state=42)

    # When creating the clients, we will only add the benign data and the attack class for that client
    for i, (train_index, test_index) in enumerate(skf.split(train_df[X_columns], train_df[y_column])):
        if binary_classifier:
            print(f"i: {i} = i % 2 = {i % 2}")
            if i % 2 == 0:
                print("Benign only")
                # Create a new dataframe for the client data with only benign traffic
                client_df = pd.concat([train_df.iloc[test_index][train_df[y_column] != 1]], ignore_index=True)
                fl_X_train.append(client_df[X_columns])
                fl_y_train.append(client_df[y_column])
            else:
                print("Both")
                # Create a new dataframe for the client data
                fl_X_train.append(train_df[X_columns].iloc[test_index])
                fl_y_train.append(train_df[y_column].iloc[test_index])
        else:
            # Create a new dataframe for the client data
            client_df = pd.concat([train_df.iloc[test_index][(train_df[y_column] == 0) | (train_df[y_column] == i+1)]], ignore_index=True)
            fl_X_train.append(client_df[X_columns])
            fl_y_train.append(client_df[y_column])

elif METHOD == 'HALF_BENIGN':
    print(f"{Colours.YELLOW.value}HALF_BENIGN METHOD{Colours.NORMAL.value} with {class_size} class classifier")

    num_splits = 10

    # Split into 10 client data
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

    # For i % 2 == 0, add only benign data
    # For i % 2 == 1, add all data
    for i, (train_index, test_index) in enumerate(skf.split(train_df[X_columns], train_df[y_column])):
        if i % 2 == 0:
            print("Benign only")
            # Create a new dataframe for the client data with only benign traffic
            client_df = pd.concat([train_df.iloc[test_index][train_df[y_column] == 0]], ignore_index=True)
            fl_X_train.append(client_df[X_columns])
            fl_y_train.append(client_df[y_column])
        else:
            print("All Classes")
            fl_X_train.append(train_df[X_columns].iloc[test_index])
            fl_y_train.append(train_df[y_column].iloc[test_index])
else:
    print(f"{Colours.RED.value}ERROR: Method {METHOD} not recognised{Colours.NORMAL.value}")
    exit()
# Out:
# HALF_BENIGN METHOD with 2 class classifier
# Benign only
# C:\Users\Jon\AppData\Local\Temp\ipykernel_26232\697725314.py:99: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   client_df = pd.concat([train_df.iloc[test_index][train_df[y_column] == 0]], ignore_index=True)
# All Classes
# Benign only
# C:\Users\Jon\AppData\Local\Temp\ipykernel_26232\697725314.py:99: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   client_df = pd.concat([train_df.iloc[test_index][train_df[y_column] == 0]], ignore_index=True)
# All Classes
# Benign only
# C:\Users\Jon\AppData\Local\Temp\ipykernel_26232\697725314.py:99: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   client_df = pd.concat([train_df.iloc[test_index][train_df[y_column] == 0]], ignore_index=True)
# All Classes
# Benign only
# C:\Users\Jon\AppData\Local\Temp\ipykernel_26232\697725314.py:99: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   client_df = pd.concat([train_df.iloc[test_index][train_df[y_column] == 0]], ignore_index=True)
# All Classes
# Benign only
# All Classes
# C:\Users\Jon\AppData\Local\Temp\ipykernel_26232\697725314.py:99: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   client_df = pd.concat([train_df.iloc[test_index][train_df[y_column] == 0]], ignore_index=True)

# %%
NUM_OF_CLIENTS = len(fl_X_train)

for i in range(len(fl_X_train)):
    # Show the unique values in the y column
    (f"Client ID: {i}")
    print(f"fl_X_train[{i}].shape: {fl_X_train[i].shape}")  
    print(f"fl_y_train[{i}].value_counts():\n{fl_y_train[i].value_counts()}")
    print(f"fl_y_train[{i}].unique(): {fl_y_train[i].unique()}\n")

# Check that fl_X_train[0] and fl_X_train[1] contain different data
print(f"fl_X_train[0].equals(fl_X_train[1]): {fl_X_train[0].equals(fl_X_train[1])}")
# Out:
# fl_X_train[0].shape: (4274, 46)
# fl_y_train[0].value_counts():
# 0    4274
# Name: label, dtype: int64
# fl_y_train[0].unique(): [0]
#
# fl_X_train[1].shape: (181732, 46)
# fl_y_train[1].value_counts():
# 1    177458
# 0      4274
# Name: label, dtype: int64
# fl_y_train[1].unique(): [1 0]
#
# fl_X_train[2].shape: (4274, 46)
# fl_y_train[2].value_counts():
# 0    4274
# Name: label, dtype: int64
# fl_y_train[2].unique(): [0]
#
# fl_X_train[3].shape: (181732, 46)
# fl_y_train[3].value_counts():
# 1    177458
# 0      4274
# Name: label, dtype: int64
# fl_y_train[3].unique(): [1 0]
#
# fl_X_train[4].shape: (4274, 46)
# fl_y_train[4].value_counts():
# 0    4274
# Name: label, dtype: int64
# fl_y_train[4].unique(): [0]
#
# fl_X_train[5].shape: (181732, 46)
# fl_y_train[5].value_counts():
# 1    177458
# 0      4274
# Name: label, dtype: int64
# fl_y_train[5].unique(): [1 0]
#
# fl_X_train[6].shape: (4275, 46)
# fl_y_train[6].value_counts():
# 0    4275
# Name: label, dtype: int64
# fl_y_train[6].unique(): [0]
#
# fl_X_train[7].shape: (181732, 46)
# fl_y_train[7].value_counts():
# 1    177457
# 0      4275
# Name: label, dtype: int64
# fl_y_train[7].unique(): [1 0]
#
# fl_X_train[8].shape: (4275, 46)
# fl_y_train[8].value_counts():
# 0    4275
# Name: label, dtype: int64
# fl_y_train[8].unique(): [0]
#
# fl_X_train[9].shape: (181732, 46)
# fl_y_train[9].value_counts():
# 1    177457
# 0      4275
# Name: label, dtype: int64
# fl_y_train[9].unique(): [1 0]
#
# fl_X_train[0].equals(fl_X_train[1]): False

# %% [markdown]
# Prepare an output directory where we can store the results of the federated learning

# %%
# Create an "Output" directory if it doesnt exist already
if not os.path.exists("Output"):
    os.makedirs("Output")

sub_dir_name = f"train_size-{train_size}"

# if sub_dir_name does not exist, create it
if not os.path.exists(f"Output/{sub_dir_name}"):
    os.makedirs(f"Output/{sub_dir_name}")

test_directory_name = f"{METHOD}_Classifier-{class_size}_Clients-{NUM_OF_CLIENTS}"

# Create an "Output/{METHOD}-{NUM_OF_CLIENTS}-{NUM_OF_ROUNDS}" directory if it doesnt exist already
if not os.path.exists(f"Output/{sub_dir_name}/{test_directory_name}"):
    os.makedirs(f"Output/{sub_dir_name}/{test_directory_name}")

# Ensure the directory is empty
for file in os.listdir(f"Output/{sub_dir_name}/{test_directory_name}"):
    file_path = os.path.join(f"Output/{sub_dir_name}/{test_directory_name}", file)
    if os.path.isfile(file_path):
        os.unlink(file_path)

# Original training size is the sum of all the fl_X_train sizes
original_training_size = 0
for i in range(len(fl_X_train)):
    original_training_size += fl_X_train[i].shape[0]

# Write this same info to the output directory/Class Split Info.txt
with open(f"Output/{sub_dir_name}/{test_directory_name}/Class Split Info.txt", "w") as f:
    for i in range(len(fl_X_train)):
        f.write(f"Client ID: {i}\n")
        f.write(f"fl_X_train.shape: {fl_X_train[i].shape}\n")
        f.write(f"Training data used {original_training_size}")
        f.write(f"fl_y_train.value_counts():\n{fl_y_train[i].value_counts()}\n")
        f.write(f"fl_y_train.unique(): {fl_y_train[i].unique()}\n\n")

# %% [markdown]
# ### Convert the training dataset

# %%
# Convert the testing daya to X_test and y_test ndarrays
X_test = test_df[X_columns].to_numpy()
y_test = test_df[y_column].to_numpy()

# %%
num_unique_classes = len(train_df[y_column].unique())

train_df_shape = train_df.shape
test_df_shape = test_df.shape

# We are now done with the train_df and test_df dataframes, so we can delete them to free up memory
del train_df
del test_df
del client_df

# %% [markdown]
# ---
# ### Data check

# %%
print("NUM_CLIENTS:", NUM_OF_CLIENTS)

print("NUM_ROUNDS:", NUM_OF_ROUNDS)
print()


print("Original training size: {}".format(original_training_size))


print("Checking training data split groups")
for i in range(len(fl_X_train)):
    print(i, ":", "X Shape", fl_X_train[i].shape, "Y Shape", fl_y_train[i].shape)


# Print the sizes of X_test and y_test
print("\nChecking testing data")
print("X_test size: {}".format(X_test.shape))
print("y_test size: {}".format(y_test.shape))

print("\nDeploy Simulation")
# Out:
# NUM_CLIENTS: 10
# NUM_ROUNDS: 10
#
# Original training size: 930032
# Checking training data split groups
# 0 : X Shape (4274, 46) Y Shape (4274,)
# 1 : X Shape (181732, 46) Y Shape (181732,)
# 2 : X Shape (4274, 46) Y Shape (4274,)
# 3 : X Shape (181732, 46) Y Shape (181732,)
# 4 : X Shape (4274, 46) Y Shape (4274,)
# 5 : X Shape (181732, 46) Y Shape (181732,)
# 6 : X Shape (4275, 46) Y Shape (4275,)
# 7 : X Shape (181732, 46) Y Shape (181732,)
# 8 : X Shape (4275, 46) Y Shape (4275,)
# 9 : X Shape (181732, 46) Y Shape (181732,)
#
# Checking testing data
# X_test size: (10340161, 46)
# y_test size: (10340161,)
#
# Deploy Simulation

# %% [markdown]
# ----
# # Federated Learning
# ## Import the libraries and print the versions

# %%
import os
import flwr as fl
import numpy as np
import tensorflow as tf

# Make TensorFlow log less verbose
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dropout

# %% [markdown]
# Define the Client and Server code

# %%
import os
import flwr as fl
import numpy as np
import tensorflow as tf

print('scikit-learn {}.'.format(sklearn.__version__))
print("flwr", fl.__version__)
print("numpy", np.__version__)
print("tf", tf.__version__)
# Make TensorFlow log less verbose
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dropout

import datetime

client_evaluations = []

class NumpyFlowerClient(fl.client.NumPyClient):
    def __init__(self, cid, model, train_data, train_labels):
        self.model = model
        self.cid = cid
        self.train_data = train_data
        self.train_labels = train_labels

    def get_parameters(self, config):
        return self.model.get_weights()

    def fit(self, parameters, config):
        self.model.set_weights(parameters)
        print ("Client ", self.cid, "Training...")
        self.model.fit(self.train_data, self.train_labels, epochs=5, batch_size=32)
        print ("Client ", self.cid, "Training complete...")
        return self.model.get_weights(), len(self.train_data), {}

    def evaluate(self, parameters, config):
        self.model.set_weights(parameters)
        print ("Client ", self.cid, "Evaluating...")
        loss, accuracy = self.model.evaluate(self.train_data, self.train_labels, batch_size=32)
        print(f"{Colours.YELLOW.value}Client {self.cid} evaluation complete - Accuracy: {accuracy:.6f}, Loss: {loss:.6f}{Colours.NORMAL.value}")

        # Write the same message to the "Output/{cid}_Evaluation.txt" file
        with open(f"Output/{sub_dir_name}/{test_directory_name}/{self.cid}_Evaluation.txt", "a") as f:
            f.write(f"{datetime.datetime.now()} - Client {self.cid} evaluation complete - Accuracy: {accuracy:.6f}, Loss: {loss:.6f}\n")

            # Close the file
            f.close()

        return loss, len(self.train_data), {"accuracy": accuracy}
    
    def predict(self, incoming):
        prediction = np.argmax( self.model.predict(incoming) ,axis=1)
        return prediction

def client_fn(cid: str) -> NumpyFlowerClient:
    """Create a Flower client representing a single organization."""

    # Load model
    #model = tf.keras.applications.MobileNetV2((32, 32, 3), classes=10, weights=None)
    #model.compile("adam", "sparse_categorical_crossentropy", metrics=["accuracy"])

    print ("Client ID:", cid)

    model = Sequential([
      #Flatten(input_shape=(79,1)),
      Flatten(input_shape=(fl_X_train[0].shape[1] , 1)),
      Dense(50, activation='relu'),  
      Dense(25, activation='relu'),  
      Dense(num_unique_classes, activation='softmax')
    ])
    
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

   
    partition_id = int(cid)
    X_train_c = fl_X_train[partition_id]
    y_train_c = fl_y_train[partition_id]

    # Create a  single Flower client representing a single organization
    return NumpyFlowerClient(cid, model, X_train_c, y_train_c)


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
eval_count = 0

def get_evaluate_fn(server_model):
    global eval_count
    """Return an evaluation function for server-side evaluation."""
    # The `evaluate` function will be called after every round
    
    
    def evaluate(server_round, parameters, config):
        global eval_count
        
        # Update model with the latest parameters
        server_model.set_weights(parameters)
        print (f"Server Evaluating... Evaluation Count:{eval_count}")
        loss, accuracy = server_model.evaluate(X_test, y_test)
        
        y_pred = server_model.predict(X_test)
        print ("Prediction: ", y_pred, y_pred.shape)
        #cmatrix = confusion_matrix(y_test, np.rint(y_pred))
        #print ("confusion_matrix:", cmatrix, cmatrix.shape)
                        
        print(f"{Colours.YELLOW.value}Server evaluation complete - Accuracy: {accuracy:.4f}, Loss: {loss:.4f}{Colours.NORMAL.value}")

        # Write the same message to the "Output/Server_Evaluation.txt" file
        with open(f"Output/{sub_dir_name}/{test_directory_name}/Server_Evaluation.txt", "a") as f:
            f.write(f"{datetime.datetime.now()} - {server_round} : Server evaluation complete - Accuracy: {accuracy:.4f}, Loss: {loss:.4f}\n")

            # Close the file
            f.close()
        
        np.save("y_pred-" + str(eval_count) + ".npy", y_pred)
        #np.save("cmatrix-" + str(eval_count) + ".npy", cmatrix)
        eval_count = eval_count + 1
        
        return loss, {"accuracy": accuracy}
    return evaluate



server_model = Sequential([
    #Flatten(input_shape=(79,1)),
    Flatten(input_shape=(fl_X_train[0].shape[1] , 1)),
    Dense(50, activation='relu'),  
    Dense(25, activation='relu'),  
    Dense(num_unique_classes, activation='softmax')
])


server_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Create FedAvg strategy
strategy = fl.server.strategy.FedAvg(
        fraction_fit=1.0,
        fraction_evaluate=0.5,
        min_fit_clients=2, #10,
        min_evaluate_clients=2, #5,
        min_available_clients=2, #10,
        evaluate_fn=get_evaluate_fn(server_model),
        #evaluate_metrics_aggregation_fn=weighted_average,
)
# Out:
# scikit-learn 1.2.0.
# flwr 1.4.0
# numpy 1.24.2
# tf 2.11.0

# %%
# %%time
print (f"{Colours.YELLOW.value}\nDeploy simulation... Method = {METHOD} - {class_size_map[num_unique_classes]} ({class_size}) Classifier")
print (f"Number of Clients = {NUM_OF_CLIENTS}\n")
print (f"Writing output to: {sub_dir_name}/{test_directory_name}\n{Colours.NORMAL.value}")

# Output the same information to the Output/Run_details.txt file
with open(f"Output/{sub_dir_name}/{test_directory_name}/Run_details.txt", "a") as f:
    f.write(f"{datetime.datetime.now()} - Deploy simulation... Method = {METHOD} - {class_size_map[num_unique_classes]} ({class_size}) Classifier\n")
    f.write(f"{datetime.datetime.now()} - Number of Clients = {NUM_OF_CLIENTS}\n")

    # Write Original train_df size
    f.write(f"{datetime.datetime.now()} - Original train_df size: {train_df_shape}\n")

    # Write the training data split groups
    for i in range(len(fl_X_train)):
        f.write(f"{datetime.datetime.now()} - {i}: X Shape {fl_X_train[i].shape}, Y Shape {fl_y_train[i].shape}\n")

    # Write the testing data
    f.write(f"{datetime.datetime.now()} - X_test size: {X_test.shape}\n")
    f.write(f"{datetime.datetime.now()} - y_test size: {y_test.shape}\n")
    
# close the file
f.close()

start_time = datetime.datetime.now()

# Start simulation
fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_OF_CLIENTS,
    config=fl.server.ServerConfig(num_rounds=NUM_OF_ROUNDS),
    strategy=strategy,
)

end_time = datetime.datetime.now()
print("Total time taken: ", end_time - start_time)

print (f"{Colours.YELLOW.value} SIMULATION COMPLETE. Method = {METHOD} - {class_size_map[num_unique_classes]} ({class_size}) Classifier")
print (f"Number of Clients = {NUM_OF_CLIENTS}{Colours.NORMAL.value}\n")

# Output the same information to the Output/Run_details.txt file
with open(f"Output/{sub_dir_name}/{test_directory_name}/Run_details.txt", "a") as f:
    f.write(f"{datetime.datetime.now()} - SIMULATION COMPLETE. Method = {METHOD} - {class_size_map[num_unique_classes]} ({class_size}) Classifier\n")
    f.write(f"{datetime.datetime.now()} - Total time taken: {end_time - start_time}\n")
# Out:
# INFO flwr 2023-07-15 13:41:55,623 | app.py:146 | Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# Deploy simulation... Method = HALF_BENIGN - Binary (2) Classifier
# Number of Clients = 10
#
# Writing output to: train_size-1817320/HALF_BENIGN_Classifier-2_Clients-10
# 2023-07-15 13:42:01,384	INFO worker.py:1636 -- Started a local Ray instance.
# INFO flwr 2023-07-15 13:42:05,582 | app.py:180 | Flower VCE: Ray initialized with resources: {'GPU': 1.0, 'memory': 31215680718.0, 'node:127.0.0.1': 1.0, 'object_store_memory': 15607840358.0, 'CPU': 24.0}
# INFO flwr 2023-07-15 13:42:05,583 | server.py:86 | Initializing global parameters
# INFO flwr 2023-07-15 13:42:05,583 | server.py:273 | Requesting initial parameters from one random client
# INFO flwr 2023-07-15 13:42:09,739 | server.py:277 | Received initial parameters from one random client
# INFO flwr 2023-07-15 13:42:09,739 | server.py:88 | Evaluating initial parameters
# (launch_and_get_parameters pid=31984) Client ID: 2
# Server Evaluating... Evaluation Count:0
# 323131/323131 [==============================] - 229s 707us/step - loss: 1.0544 - accuracy: 0.1565
# 323131/323131 [==============================] - 209s 646us/step
# INFO flwr 2023-07-15 13:51:36,362 | server.py:91 | initial parameters (loss, other metrics): 1.0543588399887085, {'accuracy': 0.15654368698596954}
# INFO flwr 2023-07-15 13:51:36,363 | server.py:101 | FL starting
# DEBUG flwr 2023-07-15 13:51:36,364 | server.py:218 | fit_round 1: strategy sampled 10 clients (out of 10)
# Prediction:  [[0.67037696 0.329623  ]
#  [0.7040978  0.2959022 ]
#  [0.64444405 0.35555592]
#  ...
#  [0.4926274  0.5073726 ]
#  [0.6486422  0.3513578 ]
#  [0.6675789  0.33242112]] (10340161, 2)
# Server evaluation complete - Accuracy: 0.1565, Loss: 1.0544
# (launch_and_fit pid=31984) Client ID: 0
# (launch_and_fit pid=31984) Client  0 Training...
# (launch_and_fit pid=31984) Epoch 1/5
# (launch_and_fit pid=31984)
# (launch_and_fit pid=31984)   1/134 [..............................] - ETA: 1:25 - loss: 0.4063 - accuracy: 0.8125
# (launch_and_fit pid=31984)  37/134 [=======>......................] - ETA: 0s - loss: 0.0521 - accuracy: 0.9882
# (launch_and_fit pid=31984)
# (launch_and_fit pid=31984)  76/134 [================>.............] - ETA: 0s - loss: 0.0260 - accuracy: 0.9942
# (launch_and_fit pid=31984)
# (launch_and_fit pid=31984) 114/134 [========================>.....] - ETA: 0s - loss: 0.0175 - accuracy: 0.9962
# (launch_and_fit pid=31984) 134/134 [==============================] - 1s 1ms/step - loss: 0.0151 - accuracy: 0.9967
# (launch_and_fit pid=31984) Epoch 2/5
# (launch_and_fit pid=31984)
# (launch_and_fit pid=31984)   1/134 [..............................] - ETA: 0s - loss: 5.6994e-04 - accuracy: 1.0000
# (launch_and_fit pid=31984)  43/134 [========>.....................] - ETA: 0s - loss: 4.3513e-04 - accuracy: 1.0000
# (launch_and_fit pid=31984)
# (launch_and_fit pid=31984)  81/134 [=================>............] - ETA: 0s - loss: 3.6878e-04 - accuracy: 1.0000
# (launch_and_fit pid=31984) 123/134 [==========================>...] - ETA: 0s - loss: 3.3941e-04 - accuracy: 1.0000
# (launch_and_fit pid=31984) 134/134 [==============================] - 0s 1ms/step - loss: 3.2683e-04 - accuracy: 1.0000
# (launch_and_fit pid=31984) Epoch 3/5
# (launch_and_fit pid=31984)
# (launch_and_fit pid=31984)   1/134 [..............................] - ETA: 0s - loss: 1.2126e-04 - accuracy: 1.0000
# (launch_and_fit pid=31984)
# (launch_and_fit pid=31984)  40/134 [=======>......................] - ETA: 0s - loss: 1.8953e-04 - accuracy: 1.0000
# (launch_and_fit pid=31984)
# (launch_and_fit pid=31984)  81/134 [=================>............] - ETA: 0s - loss: 1.6497e-04 - accuracy: 1.0000
# (launch_and_fit pid=31984) 125/134 [==========================>...] - ETA: 0s - loss: 1.4486e-04 - accuracy: 1.0000
# (launch_and_fit pid=31984) 134/134 [==============================] - 0s 1ms/step - loss: 1.4270e-04 - accuracy: 1.0000
# (launch_and_fit pid=31984) Epoch 4/5
# (launch_and_fit pid=31984)
# (launch_and_fit pid=31984)   1/134 [..............................] - ETA: 0s - loss: 1.1685e-04 - accuracy: 1.0000
# (launch_and_fit pid=31984)
# (launch_and_fit pid=31984)  46/134 [=========>....................] - ETA: 0s - loss: 8.4437e-05 - accuracy: 1.0000
# (launch_and_fit pid=31984)
# (launch_and_fit pid=31984)  90/134 [===================>..........] - ETA: 0s - loss: 7.7840e-05 - accuracy: 1.0000
# (launch_and_fit pid=31984) 130/134 [============================>.] - ETA: 0s - loss: 7.1943e-05 - accuracy: 1.0000
# (launch_and_fit pid=31984) 134/134 [==============================] - 0s 1ms/step - loss: 7.1669e-05 - accuracy: 1.0000
# (launch_and_fit pid=31984) Epoch 5/5
# (launch_and_fit pid=31984)
# (launch_and_fit pid=31984)   1/134 [..............................] - ETA: 0s - loss: 6.3001e-05 - accuracy: 1.0000
# (launch_and_fit pid=31984)
# (launch_and_fit pid=31984)  45/134 [=========>....................] - ETA: 0s - loss: 4.9174e-05 - accuracy: 1.0000
# (launch_and_fit pid=31984)
# (launch_and_fit pid=31984)  90/134 [===================>..........] - ETA: 0s - loss: 4.5260e-05 - accuracy: 1.0000
# (launch_and_fit pid=31984) 134/134 [==============================] - ETA: 0s - loss: 4.3631e-05 - accuracy: 1.0000
# (launch_and_fit pid=31984) 134/134 [==============================] - 0s 1ms/step - loss: 4.3631e-05 - accuracy: 1.0000
# (launch_and_fit pid=31984) Client  0 Training complete...
# (launch_and_fit pid=32044) Client ID: 2
# (launch_and_fit pid=32044) Client  2 Training...
# (launch_and_fit pid=31468) Client  8 Training...
# (launch_and_fit pid=32044) Epoch 1/5
# (launch_and_fit pid=30712)   1/134 [..............................] - ETA: 1:30 - loss: 0.6009 - accuracy: 0.6562
# (launch_and_fit pid=30712)   1/134 [..............................] - ETA: 1:30 - loss: 0.6009 - accuracy: 0.6562
# (launch_and_fit pid=32044)
# (launch_and_fit pid=32044)   1/134 [..............................] - ETA: 1:31 - loss: 0.7086 - accuracy: 0.6875
# (launch_and_fit pid=32044)  38/134 [=======>......................] - ETA: 0s - loss: 0.0648 - accuracy: 0.9836
# (launch_and_fit pid=32044)  76/134 [================>.............] - ETA: 0s - loss: 0.0330 - accuracy: 0.9918
# (launch_and_fit pid=31608)  74/134 [===============>..............] - ETA: 0s - loss: 0.0306 - accuracy: 0.9899
# (launch_and_fit pid=31608) 112/134 [========================>.....] - ETA: 0s - loss: 0.0205 - accuracy: 0.9933
# (launch_and_fit pid=30712) 110/134 [=======================>......] - ETA: 0s - loss: 0.0213 - accuracy: 0.9937
# (launch_and_fit pid=32044) 134/134 [==============================] - 1s 1ms/step - loss: 0.0191 - accuracy: 0.9953
# (launch_and_fit pid=32044) 117/134 [=========================>....] - ETA: 0s - loss: 4.0399e-04 - accuracy: 1.0000
# (launch_and_fit pid=31920)  227/5680 [>.............................] - ETA: 7s - loss: 0.1651 - accuracy: 0.9419
# (launch_and_fit pid=31920)  268/5680 [>.............................] - ETA: 7s - loss: 0.1453 - accuracy: 0.9486
# (launch_and_fit pid=30712)  41/134 [========>.....................] - ETA: 0s - loss: 1.8182e-04 - accuracy: 1.0000
# (launch_and_fit pid=30832)  394/5680 [=>............................] - ETA: 6s - loss: 0.1126 - accuracy: 0.9610
# (launch_and_fit pid=30832)  590/5680 [==>...........................] - ETA: 6s - loss: 0.0846 - accuracy: 0.9695
# (launch_and_fit pid=32044) Client  2 Training complete...
# (launch_and_fit pid=31920)  786/5680 [===>..........................] - ETA: 6s - loss: 0.0719 - accuracy: 0.9738
# (launch_and_fit pid=31920)  978/5680 [====>.........................] - ETA: 5s - loss: 0.0626 - accuracy: 0.9767
# (launch_and_fit pid=30832) 1136/5680 [=====>........................] - ETA: 5s - loss: 0.0569 - accuracy: 0.9784
# (launch_and_fit pid=31720) 1355/5680 [======>.......................] - ETA: 5s - loss: 0.0503 - accuracy: 0.9809
# (launch_and_fit pid=30832) 1895/5680 [=========>....................] - ETA: 4s - loss: 0.0438 - accuracy: 0.9829
# (launch_and_fit pid=31720) 2102/5680 [==========>...................] - ETA: 4s - loss: 0.0407 - accuracy: 0.9836
# (launch_and_fit pid=30832) 2289/5680 [===========>..................] - ETA: 3s - loss: 0.0403 - accuracy: 0.9841
# (launch_and_fit pid=31920) 2470/5680 [============>.................] - ETA: 3s - loss: 0.0404 - accuracy: 0.9838
# (launch_and_fit pid=31920) 2520/5680 [============>.................] - ETA: 3s - loss: 0.0400 - accuracy: 0.9840
# (launch_and_fit pid=31720) 2657/5680 [=============>................] - ETA: 3s - loss: 0.0369 - accuracy: 0.9848
# (launch_and_fit pid=31720) 2707/5680 [=============>................] - ETA: 3s - loss: 0.0366 - accuracy: 0.9849
# (launch_and_fit pid=31920) 2871/5680 [==============>...............] - ETA: 3s - loss: 0.0386 - accuracy: 0.9845
# (launch_and_fit pid=31720) 3422/5680 [=================>............] - ETA: 2s - loss: 0.0336 - accuracy: 0.9862
# (launch_and_fit pid=31720) 3472/5680 [=================>............] - ETA: 2s - loss: 0.0355 - accuracy: 0.9862
# (launch_and_fit pid=31720) 3629/5680 [==================>...........] - ETA: 2s - loss: 0.0348 - accuracy: 0.9864
# (launch_and_fit pid=31720) 3679/5680 [==================>...........] - ETA: 2s - loss: 0.0346 - accuracy: 0.9865
# (launch_and_fit pid=31920) 3832/5680 [===================>..........] - ETA: 1s - loss: 0.0342 - accuracy: 0.9861
# (launch_and_fit pid=31720) Client ID: 5 [repeated 8x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (launch_and_fit pid=31720) Client  5 Training... [repeated 7x across cluster]
# (launch_and_fit pid=31720) 3985/5680 [====================>.........] - ETA: 1s - loss: 0.0339 - accuracy: 0.9867
# (launch_and_fit pid=31608) Epoch 5/5 [repeated 24x across cluster]
# (launch_and_fit pid=31720) 4188/5680 [=====================>........] - ETA: 1s - loss: 0.0333 - accuracy: 0.9869
# (launch_and_fit pid=31720) 4235/5680 [=====================>........] - ETA: 1s - loss: 0.0332 - accuracy: 0.9870
# (launch_and_fit pid=31720) 4385/5680 [======================>.......] - ETA: 1s - loss: 0.0327 - accuracy: 0.9872
# (launch_and_fit pid=31720) 4435/5680 [======================>.......] - ETA: 1s - loss: 0.0326 - accuracy: 0.9872
# (launch_and_fit pid=30476)  [repeated 432x across cluster]
# (launch_and_fit pid=31608)   1/134 [..............................] - ETA: 0s - loss: 7.1540e-05 - accuracy: 1.0000 [repeated 46x across cluster]
# (launch_and_fit pid=31416) 1667/5680 [=======>......................] - ETA: 4s - loss: 0.0467 - accuracy: 0.9816 [repeated 38x across cluster]
# (launch_and_fit pid=31416) 3371/5680 [================>.............] - ETA: 2s - loss: 0.0351 - accuracy: 0.9856 [repeated 33x across cluster]
# (launch_and_fit pid=30476) 3217/5680 [===============>..............] - ETA: 2s - loss: 0.0352 - accuracy: 0.9855 [repeated 21x across cluster]
# (launch_and_fit pid=31920) 4830/5680 [========================>.....] - ETA: 0s - loss: 0.0315 - accuracy: 0.9869 [repeated 14x across cluster]
# (launch_and_fit pid=31920) 4723/5680 [=======================>......] - ETA: 1s - loss: 0.0316 - accuracy: 0.9869 [repeated 17x across cluster]
# (launch_and_fit pid=31608) 134/134 [==============================] - 0s 1ms/step - loss: 2.4541e-05 - accuracy: 1.0000 [repeated 19x across cluster]
# (launch_and_fit pid=31720) 5114/5680 [==========================>...] - ETA: 0s - loss: 0.0309 - accuracy: 0.9876
# (launch_and_fit pid=31720) 5166/5680 [==========================>...] - ETA: 0s - loss: 0.0308 - accuracy: 0.9876
# (launch_and_fit pid=31416) 5043/5680 [=========================>....] - ETA: 0s - loss: 0.0302 - accuracy: 0.9873 [repeated 20x across cluster]
# (launch_and_fit pid=31416)  377/5680 [>.............................] - ETA: 7s - loss: 0.1101 - accuracy: 0.9600 [repeated 21x across cluster]
# (launch_and_fit pid=31416) 1869/5680 [========>.....................] - ETA: 4s - loss: 0.0445 - accuracy: 0.9825 [repeated 18x across cluster]
# (launch_and_fit pid=31416)  565/5680 [=>............................] - ETA: 6s - loss: 0.0837 - accuracy: 0.9686 [repeated 24x across cluster]
# (launch_and_fit pid=31720) 5323/5680 [===========================>..] - ETA: 0s - loss: 0.0305 - accuracy: 0.9877
# (launch_and_fit pid=31720) 5371/5680 [===========================>..] - ETA: 0s - loss: 0.0305 - accuracy: 0.9877
# (launch_and_fit pid=31720) 5527/5680 [============================>.] - ETA: 0s - loss: 0.0303 - accuracy: 0.9878
# (launch_and_fit pid=31720)  741/5680 [==>...........................] - ETA: 6s - loss: 0.0707 - accuracy: 0.9744 [repeated 22x across cluster]
# (launch_and_fit pid=31608) Client  6 Training complete... [repeated 3x across cluster]
# (launch_and_fit pid=31720)  937/5680 [===>..........................] - ETA: 5s - loss: 0.0610 - accuracy: 0.9774 [repeated 19x across cluster]
# (launch_and_fit pid=31416) 1108/5680 [====>.........................] - ETA: 5s - loss: 0.0588 - accuracy: 0.9780 [repeated 19x across cluster]
# (launch_and_fit pid=31416) 1286/5680 [=====>........................] - ETA: 5s - loss: 0.0537 - accuracy: 0.9797 [repeated 20x across cluster]
# (launch_and_fit pid=31416) 1473/5680 [======>.......................] - ETA: 5s - loss: 0.0495 - accuracy: 0.9810 [repeated 19x across cluster]
# (launch_and_fit pid=31416) 2066/5680 [=========>....................] - ETA: 4s - loss: 0.0423 - accuracy: 0.9834 [repeated 19x across cluster]
# (launch_and_fit pid=31416) 2266/5680 [==========>...................] - ETA: 3s - loss: 0.0406 - accuracy: 0.9840 [repeated 17x across cluster]
# (launch_and_fit pid=31720) 2454/5680 [===========>..................] - ETA: 3s - loss: 0.0382 - accuracy: 0.9843 [repeated 18x across cluster]
# (launch_and_fit pid=31416) 2617/5680 [============>.................] - ETA: 3s - loss: 0.0383 - accuracy: 0.9847 [repeated 17x across cluster]
# (launch_and_fit pid=30476) 2817/5680 [=============>................] - ETA: 3s - loss: 0.0372 - accuracy: 0.9848 [repeated 18x across cluster]
# (launch_and_fit pid=30476) 3016/5680 [==============>...............] - ETA: 2s - loss: 0.0362 - accuracy: 0.9852 [repeated 18x across cluster]
# (launch_and_fit pid=31416) 3578/5680 [=================>............] - ETA: 2s - loss: 0.0343 - accuracy: 0.9858 [repeated 18x across cluster]
# (launch_and_fit pid=31720) 3782/5680 [==================>...........] - ETA: 2s - loss: 0.0342 - accuracy: 0.9866 [repeated 17x across cluster]
# (launch_and_fit pid=31416) 3934/5680 [===================>..........] - ETA: 1s - loss: 0.0331 - accuracy: 0.9862 [repeated 15x across cluster]
# (launch_and_fit pid=31416) 4134/5680 [====================>.........] - ETA: 1s - loss: 0.0324 - accuracy: 0.9865 [repeated 19x across cluster]
# (launch_and_fit pid=30476) Epoch 2/5 [repeated 5x across cluster]
# (launch_and_fit pid=31416) 4329/5680 [=====================>........] - ETA: 1s - loss: 0.0318 - accuracy: 0.9867 [repeated 18x across cluster]
# (launch_and_fit pid=31720) 4535/5680 [======================>.......] - ETA: 1s - loss: 0.0323 - accuracy: 0.9872 [repeated 18x across cluster]
# (launch_and_fit pid=30476)  [repeated 280x across cluster]
# (launch_and_fit pid=30476)  154/5680 [..............................] - ETA: 5s - loss: 0.0190 - accuracy: 0.9905 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 1701/5680 [=======>......................] - ETA: 3s - loss: 0.0201 - accuracy: 0.9910 [repeated 20x across cluster]
# (launch_and_fit pid=30476) 3386/5680 [================>.............] - ETA: 2s - loss: 0.0198 - accuracy: 0.9912 [repeated 20x across cluster]
# (launch_and_fit pid=30476) 3189/5680 [===============>..............] - ETA: 2s - loss: 0.0200 - accuracy: 0.9911 [repeated 20x across cluster]
# (launch_and_fit pid=31416) 4888/5680 [========================>.....] - ETA: 0s - loss: 0.0306 - accuracy: 0.9872 [repeated 14x across cluster]
# (launch_and_fit pid=30476) 4725/5680 [=======================>......] - ETA: 1s - loss: 0.0311 - accuracy: 0.9870 [repeated 2x across cluster]
# (launch_and_fit pid=30476) 5680/5680 [==============================] - 7s 1ms/step - loss: 0.0291 - accuracy: 0.9876 [repeated 5x across cluster]
# (launch_and_fit pid=31416) 5296/5680 [==========================>...] - ETA: 0s - loss: 0.0298 - accuracy: 0.9875 [repeated 18x across cluster]
# (launch_and_fit pid=31416) 5093/5680 [=========================>....] - ETA: 0s - loss: 0.0302 - accuracy: 0.9873 [repeated 3x across cluster]
# (launch_and_fit pid=30476)  354/5680 [>.............................] - ETA: 5s - loss: 0.0224 - accuracy: 0.9900 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 1891/5680 [========>.....................] - ETA: 3s - loss: 0.0201 - accuracy: 0.9911 [repeated 20x across cluster]
# (launch_and_fit pid=31720)  564/5680 [=>............................] - ETA: 5s - loss: 0.0220 - accuracy: 0.9900 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 5489/5680 [===========================>..] - ETA: 0s - loss: 0.0304 - accuracy: 0.9874 [repeated 16x across cluster]
# (launch_and_fit pid=31416) 5650/5680 [============================>.] - ETA: 0s - loss: 0.0291 - accuracy: 0.9877 [repeated 18x across cluster]
# (launch_and_fit pid=30476)  754/5680 [==>...........................] - ETA: 4s - loss: 0.0218 - accuracy: 0.9908 [repeated 18x across cluster]
# (launch_and_fit pid=31416)  919/5680 [===>..........................] - ETA: 4s - loss: 0.0211 - accuracy: 0.9909 [repeated 17x across cluster]
# (launch_and_fit pid=30476) 1117/5680 [====>.........................] - ETA: 4s - loss: 0.0219 - accuracy: 0.9907 [repeated 20x across cluster]
# (launch_and_fit pid=30476) 1319/5680 [=====>........................] - ETA: 4s - loss: 0.0213 - accuracy: 0.9909 [repeated 18x across cluster]
# (launch_and_fit pid=30476) 1465/5680 [======>.......................] - ETA: 4s - loss: 0.0210 - accuracy: 0.9911 [repeated 18x across cluster]
# (launch_and_fit pid=31720) 5680/5680 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9912
# (launch_and_fit pid=30476) 2037/5680 [=========>....................] - ETA: 3s - loss: 0.0208 - accuracy: 0.9910 [repeated 19x across cluster]
# (launch_and_fit pid=31920) 2265/5680 [==========>...................] - ETA: 3s - loss: 0.0199 - accuracy: 0.9911 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 2438/5680 [===========>..................] - ETA: 3s - loss: 0.0202 - accuracy: 0.9910 [repeated 23x across cluster]
# (launch_and_fit pid=31920) 2605/5680 [============>.................] - ETA: 3s - loss: 0.0198 - accuracy: 0.9911 [repeated 21x across cluster]
# (launch_and_fit pid=30476) 2802/5680 [=============>................] - ETA: 2s - loss: 0.0201 - accuracy: 0.9911 [repeated 20x across cluster]
# (launch_and_fit pid=31416) 3015/5680 [==============>...............] - ETA: 2s - loss: 0.0198 - accuracy: 0.9911 [repeated 20x across cluster]
# (launch_and_fit pid=30476) 3577/5680 [=================>............] - ETA: 2s - loss: 0.0198 - accuracy: 0.9912 [repeated 20x across cluster]
# (launch_and_fit pid=30476) 3773/5680 [==================>...........] - ETA: 1s - loss: 0.0197 - accuracy: 0.9913 [repeated 19x across cluster]
# (launch_and_fit pid=30476) 3965/5680 [===================>..........] - ETA: 1s - loss: 0.0195 - accuracy: 0.9914 [repeated 19x across cluster]
# (launch_and_fit pid=30476) 4165/5680 [====================>.........] - ETA: 1s - loss: 0.0195 - accuracy: 0.9914 [repeated 19x across cluster]
# (launch_and_fit pid=31920) Epoch 3/5 [repeated 5x across cluster]
# (launch_and_fit pid=30476) 4314/5680 [=====================>........] - ETA: 1s - loss: 0.0195 - accuracy: 0.9914 [repeated 19x across cluster]
# (launch_and_fit pid=31920) 4526/5680 [======================>.......] - ETA: 1s - loss: 0.0208 - accuracy: 0.9908 [repeated 20x across cluster]
# (launch_and_fit pid=31920)  [repeated 409x across cluster]
# (launch_and_fit pid=31920)  150/5680 [..............................] - ETA: 5s - loss: 0.0199 - accuracy: 0.9908 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 1686/5680 [=======>......................] - ETA: 4s - loss: 0.0179 - accuracy: 0.9917 [repeated 21x across cluster]
# (launch_and_fit pid=31720) 3332/5680 [================>.............] - ETA: 2s - loss: 0.0180 - accuracy: 0.9917 [repeated 3x across cluster]
# (launch_and_fit pid=31416) 3143/5680 [===============>..............] - ETA: 2s - loss: 0.0185 - accuracy: 0.9917 [repeated 14x across cluster]
# (launch_and_fit pid=31920) 4913/5680 [========================>.....] - ETA: 0s - loss: 0.0206 - accuracy: 0.9909 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 4720/5680 [=======================>......] - ETA: 1s - loss: 0.0206 - accuracy: 0.9909 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 5680/5680 [==============================] - 6s 1ms/step - loss: 0.0204 - accuracy: 0.9909 [repeated 5x across cluster]
# (launch_and_fit pid=30476) 5288/5680 [==========================>...] - ETA: 0s - loss: 0.0197 - accuracy: 0.9912 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 5101/5680 [=========================>....] - ETA: 0s - loss: 0.0205 - accuracy: 0.9909 [repeated 19x across cluster]
# (launch_and_fit pid=31920)  336/5680 [>.............................] - ETA: 5s - loss: 0.0198 - accuracy: 0.9907 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 1862/5680 [========>.....................] - ETA: 4s - loss: 0.0186 - accuracy: 0.9917 [repeated 20x across cluster]
# (launch_and_fit pid=31920)  525/5680 [=>............................] - ETA: 5s - loss: 0.0196 - accuracy: 0.9910 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 5473/5680 [===========================>..] - ETA: 0s - loss: 0.0205 - accuracy: 0.9908 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 5658/5680 [============================>.] - ETA: 0s - loss: 0.0204 - accuracy: 0.9909 [repeated 20x across cluster]
# (launch_and_fit pid=31920)  714/5680 [==>...........................] - ETA: 5s - loss: 0.0186 - accuracy: 0.9911 [repeated 20x across cluster]
# (launch_and_fit pid=31920)  907/5680 [===>..........................] - ETA: 5s - loss: 0.0186 - accuracy: 0.9912 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 1100/5680 [====>.........................] - ETA: 4s - loss: 0.0185 - accuracy: 0.9912 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 1287/5680 [=====>........................] - ETA: 4s - loss: 0.0180 - accuracy: 0.9916 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 1476/5680 [======>.......................] - ETA: 4s - loss: 0.0180 - accuracy: 0.9917 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 2052/5680 [=========>....................] - ETA: 3s - loss: 0.0185 - accuracy: 0.9916 [repeated 22x across cluster]
# (launch_and_fit pid=30476) 2231/5680 [==========>...................] - ETA: 3s - loss: 0.0180 - accuracy: 0.9918 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 2442/5680 [===========>..................] - ETA: 3s - loss: 0.0184 - accuracy: 0.9914 [repeated 19x across cluster]
# (launch_and_fit pid=31920) 2627/5680 [============>.................] - ETA: 3s - loss: 0.0186 - accuracy: 0.9914 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 2814/5680 [=============>................] - ETA: 3s - loss: 0.0186 - accuracy: 0.9913 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 3000/5680 [==============>...............] - ETA: 2s - loss: 0.0186 - accuracy: 0.9914 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 3573/5680 [=================>............] - ETA: 2s - loss: 0.0185 - accuracy: 0.9914 [repeated 22x across cluster]
# (launch_and_fit pid=31920) 3760/5680 [==================>...........] - ETA: 2s - loss: 0.0185 - accuracy: 0.9913 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 3947/5680 [===================>..........] - ETA: 1s - loss: 0.0186 - accuracy: 0.9913 [repeated 20x across cluster]
# (launch_and_fit pid=30476) 4155/5680 [====================>.........] - ETA: 1s - loss: 0.0179 - accuracy: 0.9919 [repeated 20x across cluster]
# (launch_and_fit pid=31920) Epoch 4/5 [repeated 5x across cluster]
# (launch_and_fit pid=31920) 4324/5680 [=====================>........] - ETA: 1s - loss: 0.0187 - accuracy: 0.9912 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 4515/5680 [======================>.......] - ETA: 1s - loss: 0.0187 - accuracy: 0.9912 [repeated 20x across cluster]
# (launch_and_fit pid=31920)  [repeated 349x across cluster]
# (launch_and_fit pid=31920)  146/5680 [..............................] - ETA: 5s - loss: 0.0147 - accuracy: 0.9927 [repeated 22x across cluster]
# (launch_and_fit pid=31920) 1702/5680 [=======>......................] - ETA: 4s - loss: 0.0181 - accuracy: 0.9914 [repeated 17x across cluster]
# (launch_and_fit pid=31920) 3392/5680 [================>.............] - ETA: 2s - loss: 0.0185 - accuracy: 0.9915 [repeated 18x across cluster]
# (launch_and_fit pid=31920) 3217/5680 [===============>..............] - ETA: 2s - loss: 0.0184 - accuracy: 0.9915 [repeated 8x across cluster]
# (launch_and_fit pid=31920) 4903/5680 [========================>.....] - ETA: 0s - loss: 0.0186 - accuracy: 0.9912 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 4710/5680 [=======================>......] - ETA: 1s - loss: 0.0187 - accuracy: 0.9912 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 5680/5680 [==============================] - 6s 1ms/step - loss: 0.0185 - accuracy: 0.9914 [repeated 5x across cluster]
# (launch_and_fit pid=31920) 5296/5680 [==========================>...] - ETA: 0s - loss: 0.0185 - accuracy: 0.9913 [repeated 19x across cluster]
# (launch_and_fit pid=31920) 5100/5680 [=========================>....] - ETA: 0s - loss: 0.0185 - accuracy: 0.9913 [repeated 18x across cluster]
# (launch_and_fit pid=31920)  352/5680 [>.............................] - ETA: 6s - loss: 0.0173 - accuracy: 0.9917 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 1857/5680 [========>.....................] - ETA: 3s - loss: 0.0180 - accuracy: 0.9916 [repeated 19x across cluster]
# (launch_and_fit pid=31920)  541/5680 [=>............................] - ETA: 5s - loss: 0.0181 - accuracy: 0.9913 [repeated 23x across cluster]
# (launch_and_fit pid=31920) 5485/5680 [===========================>..] - ETA: 0s - loss: 0.0184 - accuracy: 0.9914 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 5638/5680 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9914 [repeated 23x across cluster]
# (launch_and_fit pid=31416)  739/5680 [==>...........................] - ETA: 5s - loss: 0.0175 - accuracy: 0.9918 [repeated 20x across cluster]
# (launch_and_fit pid=31920)  932/5680 [===>..........................] - ETA: 5s - loss: 0.0177 - accuracy: 0.9917 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 1088/5680 [====>.........................] - ETA: 4s - loss: 0.0182 - accuracy: 0.9915 [repeated 16x across cluster]
# (launch_and_fit pid=31920) 1291/5680 [=====>........................] - ETA: 4s - loss: 0.0184 - accuracy: 0.9913 [repeated 20x across cluster]
# (launch_and_fit pid=31416) 1498/5680 [======>.......................] - ETA: 4s - loss: 0.0180 - accuracy: 0.9919 [repeated 19x across cluster]
# (launch_and_fit pid=31920) 2067/5680 [=========>....................] - ETA: 3s - loss: 0.0179 - accuracy: 0.9916 [repeated 19x across cluster]
# (launch_and_fit pid=31920) 2270/5680 [==========>...................] - ETA: 3s - loss: 0.0182 - accuracy: 0.9918 [repeated 17x across cluster]
# (launch_and_fit pid=31416) 2441/5680 [===========>..................] - ETA: 3s - loss: 0.0172 - accuracy: 0.9924 [repeated 18x across cluster]
# (launch_and_fit pid=31920) 2626/5680 [============>.................] - ETA: 3s - loss: 0.0182 - accuracy: 0.9917 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 2830/5680 [=============>................] - ETA: 2s - loss: 0.0180 - accuracy: 0.9917 [repeated 17x across cluster]
# (launch_and_fit pid=31920) 2983/5680 [==============>...............] - ETA: 2s - loss: 0.0178 - accuracy: 0.9918 [repeated 18x across cluster]
# (launch_and_fit pid=31720) 5680/5680 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9918
# (launch_and_fit pid=31920) 3595/5680 [=================>............] - ETA: 2s - loss: 0.0181 - accuracy: 0.9916 [repeated 19x across cluster]
# (launch_and_fit pid=31920) 3749/5680 [==================>...........] - ETA: 1s - loss: 0.0180 - accuracy: 0.9918 [repeated 16x across cluster]
# (launch_and_fit pid=31920) 3950/5680 [===================>..........] - ETA: 1s - loss: 0.0178 - accuracy: 0.9918 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 4144/5680 [====================>.........] - ETA: 1s - loss: 0.0180 - accuracy: 0.9918 [repeated 19x across cluster]
# (launch_and_fit pid=31920) Epoch 5/5 [repeated 5x across cluster]
# (launch_and_fit pid=31920) 4334/5680 [=====================>........] - ETA: 1s - loss: 0.0179 - accuracy: 0.9918 [repeated 19x across cluster]
# (launch_and_fit pid=31920) 4529/5680 [======================>.......] - ETA: 1s - loss: 0.0179 - accuracy: 0.9918 [repeated 20x across cluster]
# (launch_and_fit pid=31920)  [repeated 223x across cluster]
# (launch_and_fit pid=31920)  159/5680 [..............................] - ETA: 5s - loss: 0.0193 - accuracy: 0.9914 [repeated 20x across cluster]
# (launch_and_fit pid=31720) 1655/5680 [=======>......................] - ETA: 3s - loss: 0.0176 - accuracy: 0.9924 [repeated 3x across cluster]
# (launch_and_fit pid=31920) 3398/5680 [================>.............] - ETA: 2s - loss: 0.0180 - accuracy: 0.9916 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 3189/5680 [===============>..............] - ETA: 2s - loss: 0.0180 - accuracy: 0.9917 [repeated 17x across cluster]
# (launch_and_fit pid=31920) 4875/5680 [========================>.....] - ETA: 0s - loss: 0.0177 - accuracy: 0.9918 [repeated 18x across cluster]
# (launch_and_fit pid=31920) 4724/5680 [=======================>......] - ETA: 0s - loss: 0.0179 - accuracy: 0.9918 [repeated 19x across cluster]
# (launch_and_fit pid=31920) 5680/5680 [==============================] - 6s 1ms/step - loss: 0.0178 - accuracy: 0.9918 [repeated 5x across cluster]
# (launch_and_fit pid=31920) 5280/5680 [==========================>...] - ETA: 0s - loss: 0.0178 - accuracy: 0.9918 [repeated 18x across cluster]
# (launch_and_fit pid=31920) 5078/5680 [=========================>....] - ETA: 0s - loss: 0.0177 - accuracy: 0.9919 [repeated 20x across cluster]
# (launch_and_fit pid=31920)  372/5680 [>.............................] - ETA: 5s - loss: 0.0186 - accuracy: 0.9919 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 1879/5680 [========>.....................] - ETA: 3s - loss: 0.0167 - accuracy: 0.9924 [repeated 17x across cluster]
# (launch_and_fit pid=31920)  527/5680 [=>............................] - ETA: 4s - loss: 0.0174 - accuracy: 0.9922 [repeated 15x across cluster]
# (launch_and_fit pid=31920) 5439/5680 [===========================>..] - ETA: 0s - loss: 0.0178 - accuracy: 0.9918 [repeated 18x across cluster]
# (launch_and_fit pid=31920) 5646/5680 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 0.9918 [repeated 17x across cluster]
# (launch_and_fit pid=31920)  735/5680 [==>...........................] - ETA: 4s - loss: 0.0183 - accuracy: 0.9917 [repeated 20x across cluster]
# (launch_and_fit pid=31920)  940/5680 [===>..........................] - ETA: 4s - loss: 0.0176 - accuracy: 0.9919 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 1098/5680 [====>.........................] - ETA: 4s - loss: 0.0175 - accuracy: 0.9920 [repeated 15x across cluster]
# (launch_and_fit pid=31920) 1297/5680 [=====>........................] - ETA: 4s - loss: 0.0170 - accuracy: 0.9921 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 1482/5680 [======>.......................] - ETA: 4s - loss: 0.0169 - accuracy: 0.9923 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 2036/5680 [=========>....................] - ETA: 3s - loss: 0.0167 - accuracy: 0.9924 [repeated 18x across cluster]
# (launch_and_fit pid=31920) 2242/5680 [==========>...................] - ETA: 3s - loss: 0.0169 - accuracy: 0.9923 [repeated 20x across cluster]
# (launch_and_fit pid=31920) 2450/5680 [===========>..................] - ETA: 3s - loss: 0.0170 - accuracy: 0.9922 [repeated 19x across cluster]
# (launch_and_fit pid=31920) 2607/5680 [============>.................] - ETA: 3s - loss: 0.0169 - accuracy: 0.9923 [repeated 17x across cluster]
# (launch_and_fit pid=31920) 2813/5680 [=============>................] - ETA: 2s - loss: 0.0167 - accuracy: 0.9923 [repeated 19x across cluster]
# (launch_and_fit pid=31920) 3020/5680 [==============>...............] - ETA: 2s - loss: 0.0166 - accuracy: 0.9923 [repeated 18x across cluster]
# (launch_and_fit pid=31416) 4885/5680 [========================>.....] - ETA: 0s - loss: 0.0172 - accuracy: 0.9923
# (launch_and_fit pid=31920) 3544/5680 [=================>............] - ETA: 2s - loss: 0.0165 - accuracy: 0.9925 [repeated 17x across cluster]
# (launch_and_fit pid=31920) 3749/5680 [==================>...........] - ETA: 1s - loss: 0.0167 - accuracy: 0.9924 [repeated 19x across cluster]
# (launch_and_fit pid=31720) Client  5 Training complete...
# (launch_and_fit pid=31920) 3959/5680 [===================>..........] - ETA: 1s - loss: 0.0167 - accuracy: 0.9924 [repeated 19x across cluster]
# DEBUG flwr 2023-07-15 13:52:12,925 | server.py:232 | fit_round 1 received 10 results and 0 failures
# WARNING flwr 2023-07-15 13:52:12,939 | fedavg.py:243 | No fit_metrics_aggregation_fn provided
# Server Evaluating... Evaluation Count:1
